# %% [markdown]
# # WeatherPy v2
# My version

# %% [markdown]
# We will need to do the following:
#
# 1. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# 2. Loop through the cities list.
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
#     a. Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# 4. Build the city_url or endpoint for each city.
# 5. Log the URL and the record and set numbers.
# 6. Make an API request for each city.
# 7. Parse the JSON weather data for the following:
#     * City, country, and date
#     * Latitude and longitude
#     * Maximum temperature
#     * Humidity
#     * Cloudiness
#     * Wind speed
#
# Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %% [markdown]
# ### 1. Import our dependencies and initialize counters and an empty list that will hold the weather data.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests
import json

# Import the API key.
from config import weather_api_key

# %% [markdown]
# # Import linear regression from SpiPy
# from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Define cities

# With random
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(-44.54572751492888, 157.0203429916303), (20.919738707876647, 103.08010846736045), (21.235650077767602, 95.31138615057995), (52.522274083316745, 62.55858730341777), (63.44223051185031, 86.52542462382615), (58.46402981264663, 113.09979481688845), (-60.06600681005872, -165.76654652858426), (79.36751729505028, 93.45800262197827), (-86.46589131559325, -104.54225449980294), (65.11936115602796, -44.6299393065826), (77.89469911452565, 117.98126897437737), (-77.34068108080712, -87.52592770388856), (-86.55286373771455, 142.50672003597856), (-8.578798089347416, 86.00948302474245), (46.13830018234057, -52.87635151680162), (-32.553687202835306, -68.56915538039983), (43.4511106752785, -72.48384150950412), (36.18468741284515, 11.553393171526835), (-62.5677669150014, 115.32271461354418), (-12.534917947667978, 87.914960465474), (34.03299391049454, 152.31906992315203), (-73.75294100432909, -68.43621042361451), (-41.556316672988814, 119.44066119392141), (59.6424684632521, -63.32895750912739), (43.3906253212856, -67.83057467981286), (9.489322297339214, -85.20622857618602), (-84.20676078605874, -86.57608386340046), (-0.4685480057687954, 161.34553804458494), (-16.76746598152873, -96.66947514713752), (-67.64388483174694, -32.63847060516051), (69.98784808958092, 34.908737230998156), (-29.520868291541255, 47.9632603306533), (34.035889121672994, -63.079461282023075), (-15.797188674211512, -44.695145520785275), (-49.88214274044981, 34.47436220917288), (30.51638330655821, -48.900152173824154), (0.9174319821485852, -149.63230335611348), (42.57565160993326, 51.03285046307133), (42.00205795635813, -96.53557411691382), (27.69716013237644, 28.64061974101972), (56.26202796472802, 78.52218807753422), (-48.28238306734574, -2.465751399162599), (12.46688915642936, 58.824247809806366), (63.09168400817745, -50.4874057026945), (62.593425028703166, 128.91582334168703), (86.69198244942007, 67.32449499986095), (2.1073173190527257, 13.70877821874305), (83.32898290058287, -44.621614485003306), (51.14580428007764, 139.74905204803338), (-80.67385973303739, 124.09760730281886), (-8.920309873289668, -153.20592090897964), (-86.16497041135239, -128.71883761938955), (-68.1593710284109, -99.35080552416136), (-59.078694878789236, -153.01560318816038), (-38.143574823235554, 112.2287040012447), (-80.08228797640007, 91.6671884750287), (-50.13914242334725, 84.9046783150095), (67.63961761212872, 57.46523989929412), (-11.166167861028924, -83.93028406580804), (-52.43255970883269, 121.83933988760447), (-42.02852258156198, 33.46195609660404), (-69.42660615657266, -106.36244246110763), (23.296076172887155, -69.60436390270388), (3.556520650217152, 8.64818773873327), (83.82182789659606, -118.34746068383897), (-19.885364312767223, -171.21457312538834), (59.00705240036919, -146.2122245740579), (39.36181040057957, -4.550257255907297), (81.08200358172473, 110.03062126766105), (-83.76687815106274, 162.1234774184453), (-14.637044375159746, -66.34257941103955), (-7.884128775604637, 152.92657167007633), (-59.76494366454736, 96.19775695277525), (80.13096160177412, 154.22413536695774), (-7.4739013613412055, -109.75807987700091), (-40.74744105088097, -110.57068895717997), (30.924325360306725, 176.49764212541982), (-45.66986553927044, -36.957227789776425), (-37.49770368486794, 177.034329954157), (-14.7333301687637, -163.26897849856766), (-32.30680823963973, 34.17568193539657), (-43.510940366704595, -75.80763915409152), (-23.253036161515936, -110.39555774514979), (-69.585790191867, -177.65846616795804), (-38.66029089556992, 110.52012193909508), (35.88573125602052, -179.65845324181345), (-84.43784935981749, 138.5476889618335), (-47.97224235609796, 174.34789844737583), (77.81052225296202, -90.86626118027412), (34.10463337882511, -146.6020263859859), (-82.94563869670367, -34.46621098467702), (-55.29761572702996, 20.489411936721638), (-21.532126277231228, 117.70417137884311), (-43.23680772879986, -174.64238145131694), (-45.700747302872394, -127.09954975810939), (6.314621604390723, 97.84937670308898), (-47.8 ...

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %% [markdown]
# ### 2. Loop through the cities list.

# %%
# Make cities
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 3 of Set 1 | pakokku
# Processing Record 4 of Set 1 | lisakovsk
# Processing Record 5 of Set 1 | turukhansk
# Processing Record 6 of Set 1 | mama
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | talnakh
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | qaqortoq
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | bay roberts
# Processing Record 14 of Set 1 | mendoza
# Processing Record 15 of Set 1 | springfield
# Processing Record 16 of Set 1 | qurbah
# City not found. Skipping...
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | nemuro
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | bar harbor
# Processing Record 23 of Set 1 | puntarenas
# Processing Record 24 of Set 1 | buala
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | sao francisco
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | kuryk
# Processing Record 33 of Set 1 | south sioux city
# Processing Record 34 of Set 1 | matay
# Processing Record 35 of Set 1 | severnoye
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | salalah
# Processing Record 38 of Set 1 | paamiut
# Processing Record 39 of Set 1 | namtsy
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | sembe
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | de-kastri
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | usinsk
# Processing Record 50 of Set 1 | chicama
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | cockburn town
# Processing Record 3 of Set 2 | luba
# Processing Record 4 of Set 2 | norman wells
# Processing Record 5 of Set 2 | alofi
# Processing Record 6 of Set 2 | palmer
# Processing Record 7 of Set 2 | talavera de la reina
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | san borja
# Processing Record 10 of Set 2 | buin
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | rio grande
# Processing Record 14 of Set 2 | matata
# Processing Record 15 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | waitati
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | kahului
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | roebourne
# Processing Record 24 of Set 2 | lhokseumawe
# Processing Record 25 of Set 2 | emerald
# Processing Record 26 of Set 2 | houma
# Processing Record 27 of Set 2 | bilibino
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | higuey
# City not found. Skipping...
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | khasan
# Processing Record 33 of Set 2 | herat
# Processing Record 34 of Set 2 | san pedro
# Processing Record 35 of Set 2 | ouadda
# Processing Record 36 of Set 2 | concordia
# Processing Record 37 of Set 2 | udachnyy
# Processing Record 38 of Set 2 | sorso
# Processing Record 39 of Set 2 | willowmore
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | galle
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 2 | mecca
# Processing Record 47 of Set 2 | yarmouth
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | geraldton
# Processing Record 2 of Set 3 | mao
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | hermanus
# Processing Record 5 of Set 3 | canaries
# Processing Record 6 of Set 3 | beckley
# Processing Record 7 of Set 3 | manggar
# Processing Record 8 of Set 3 | cayenne
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | havre-saint-pierre
# Processing Record 11 of Set 3 | comodoro rivadavia
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | sitka
# Processing Record 14 of Set 3 | bambous virieux
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | ji-parana
# City not found. Skipping...
# Processing Record 17 of Set 3 | coquimbo
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | vao
# Processing Record 20 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | dombarovskiy
# Processing Record 23 of Set 3 | novobiryusinskiy
# Processing Record 24 of Set 3 | codrington
# Processing Record 25 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 3 | lensk
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | balkhash
# Processing Record 29 of Set 3 | yibin
# Processing Record 30 of Set 3 | khatanga
# Processing Record 31 of Set 3 | sinnamary
# Processing Record 32 of Set 3 | te anau
# Processing Record 33 of Set 3 | vardo
# Processing Record 34 of Set 3 | saint-georges
# Processing Record 35 of Set 3 | luangwa
# Processing Record 36 of Set 3 | asau
# Processing Record 37 of Set 3 | lac du bonnet
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | ludvika
# Processing Record 40 of Set 3 | quang ngai
# Processing Record 41 of Set 3 | torbay
# Processing Record 42 of Set 3 | bandarban
# Processing Record 43 of Set 3 | costinesti
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | marystown
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | bikaner
# Processing Record 48 of Set 3 | namie
# Processing Record 49 of Set 3 | sobolevo
# Processing Record 50 of Set 3 | luganville
# Processing Record 1 of Set 4 | faya
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | mayo
# Processing Record 4 of Set 4 | fairbanks
# Processing Record 5 of Set 4 | souillac
# Processing Record 6 of Set 4 | christchurch
# Processing Record 7 of Set 4 | hervey bay
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | atar
# Processing Record 10 of Set 4 | arraial do cabo
# Processing Record 11 of Set 4 | akdagmadeni
# Processing Record 12 of Set 4 | biltine
# Processing Record 13 of Set 4 | buldana
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | nouadhibou
# Processing Record 16 of Set 4 | cascais
# Processing Record 17 of Set 4 | port blair
# Processing Record 18 of Set 4 | belaya gora
# Processing Record 19 of Set 4 | sampit
# Processing Record 20 of Set 4 | fortuna
# Processing Record 21 of Set 4 | anori
# Processing Record 22 of Set 4 | hobyo
# Processing Record 23 of Set 4 | pevek
# Processing Record 24 of Set 4 | kerpen
# Processing Record 25 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 4 | plettenberg bay
# Processing Record 27 of Set 4 | el espinal
# Processing Record 28 of Set 4 | mabaruma
# Processing Record 29 of Set 4 | kununurra
# Processing Record 30 of Set 4 | boffa
# Processing Record 31 of Set 4 | moussoro
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | yellowknife
# Processing Record 34 of Set 4 | keffi
# Processing Record 35 of Set 4 | sechura
# Processing Record 36 of Set 4 | husavik
# Processing Record 37 of Set 4 | raymondville
# Processing Record 38 of Set 4 | liverpool
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | risaralda
# Processing Record 41 of Set 4 | hendijan
# City not found. Skipping...
# Processing Record 42 of Set 4 | sept-iles
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | lagos
# Processing Record 46 of Set 4 | dikson
# Processing Record 47 of Set 4 | garango
# Processing Record 48 of Set 4 | kiunga
# Processing Record 49 of Set 4 | aykhal
# Processing Record 50 of Set 4 | sisimiut
# Processing Record 1 of Set 5 | la ronge
# Processing Record 2 of Set 5 | katherine
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | pisco
# Processing Record 5 of Set 5 | axim
# Processing Record 6 of Set 5 | ust-ishim
# Processing Record 7 of Set 5 | villa del rosario
# Processing Record 8 of Set 5 | eureka
# Processing Record 9 of Set 5 | newport
# Processing Record 10 of Set 5 | ust-nera
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | llanes
# Processing Record 13 of Set 5 | maniitsoq
# Processing Record 14 of Set 5 | youghal
# Processing Record 15 of Set 5 | sorland
# Processing Record 16 of Set 5 | enshi
# Processing Record 17 of Set 5 | orange walk
# Processing Record 18 of Set 5 | ritchie
# Processing Record 19 of Set 5 | saint-augustin
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | zaozhuang
# Processing Record 22 of Set 5 | sciacca
# Processing Record 23 of Set 5 | jamestown
# Processing Record 24 of Set 5 | touros
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | avera
# Processing Record 27 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5 | van
# Processing Record 30 of Set 5 | lasa
# Processing Record 31 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 5 | verkhnyaya sinyachikha
# Processing Record 33 of Set 5 | port macquarie
# Processing Record 34 of Set 5 | barrow
# Processing Record 35 of Set 5 | thompson
# Processing Record 36 of Set 5 | mastic beach
# Processing Record 37 of Set 5 | paralimni
# Processing Record 38 of Set 5 | silyanah
# City not found. Skipping...
# Processing Record 39 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 5 | nantucket
# Processing Record 41 of Set 5 | upernavik
# Processing Record 42 of Set 5 | oussouye
# Processing Record 43 of Set 5 | saint anthony
# Processing Record 44 of Set 5 | lazaro cardenas
# Processing Record 45 of Set 5 | ucluelet
# Processing Record 46 of Set 5 | laguna
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | grafton
# Processing Record 49 of Set 5 | tromso
# Processing Record 50 of Set 5 | khotiv
# Processing Record 1 of Set 6 | makakilo city
# Processing Record 2 of Set 6 | dera din panah
# City not found. Skipping...
# Processing Record 3 of Set 6 | bayir
# Processing Record 4 of Set 6 | yumen
# Processing Record 5 of Set 6 | miri
# Processing Record 6 of Set 6 | evensk
# Processing Record 7 of Set 6 | ambilobe
# Processing Record 8 of Set 6 | langham
# Processing Record 9 of Set 6 | ambanja
# Processing Record 10 of Set 6 | mar del plata
# Processing Record 11 of Set 6 | vimperk
# Processing Record 12 of Set 6 | ponta do sol
# Processing Record 13 of Set 6 | greymouth
# Processing Record 14 of Set 6 | ewa beach
# Processing Record 15 of Set 6 | millau
# Processing Record 16 of Set 6 | los llanos de aridane
# Processing Record 17 of Set 6 | isangel
# Processing Record 18 of Set 6 | det udom
# Processing Record 19 of Set 6 | lesosibirsk
# Processing Record 20 of Set 6 | sao joao da barra
# Processing Record 21 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 6 | kodiak
# Processing Record 23 of Set 6 | khash
# Processing Record 24 of Set 6 | srednekolymsk
# Processing Record 25 of Set 6 | katobu
# Processing Record 26 of Set 6 | oranjemund
# Processing Record 27 of Set 6 | alexandria
# Processing Record 28 of Set 6 | racale
# Processing Record 29 of Set 6 | kamenka
# Processing Record 30 of Set 6 | tasiilaq
# Processing Record 31 of Set 6 | general cepeda
# Processing Record 32 of Set 6 | haines junction
# Processing Record 33 of Set 6 | arlit
# Processing Record 34 of Set 6 | ostersund
# Processing Record 35 of Set 6 | djambala
# Processing Record 36 of Set 6 | brae
# Processing Record 37 of Set 6 | calama
# Processing Record 38 of Set 6 | zhuanghe
# Processing Record 39 of Set 6 | sayat
# Processing Record 40 of Set 6 | skjervoy
# Processing Record 41 of Set 6 | saint-philippe
# Processing Record 42 of Set 6 | yambio
# Processing Record 43 of Set 6 | haguenau
# Processing Record 44 of Set 6 | tuatapere
# Processing Record 45 of Set 6 | shitanjing
# Processing Record 46 of Set 6 | ayr
# Processing Record 47 of Set 6 | xam nua
# Processing Record 48 of Set 6 | ballstad
# City not found. Skipping...
# Processing Record 49 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | kaitangata
# Processing Record 2 of Set 7 | teguise
# Processing Record 3 of Set 7 | lavrentiya
# Processing Record 4 of Set 7 | kieta
# Processing Record 5 of Set 7 | bonavista
# Processing Record 6 of Set 7 | awjilah
# Processing Record 7 of Set 7 | kysyl-syr
# Processing Record 8 of Set 7 | samarai
# Processing Record 9 of Set 7 | muisne
# Processing Record 10 of Set 7 | waingapu
# Processing Record 11 of Set 7 | bethlehem
# Processing Record 12 of Set 7 | labytnangi
# Processing Record 13 of Set 7 | puerto narino
# Processing Record 14 of Set 7 | vila
# Processing Record 15 of Set 7 | champerico
# Processing Record 16 of Set 7 | vila franca do campo
# Processing Record 17 of Set 7 | am timan
# Processing Record 18 of Set 7 | rtishchevo
# Processing Record 19 of Set 7 | bosaso
# Processing Record 20 of Set 7 | merrill
# Processing Record 21 of Set 7 | ahipara
# Processing Record 22 of Set 7 | hovd
# Processing Record 23 of Set 7 | voi
# Processing Record 24 of Set 7 | santa cruz de la palma
# Processing Record 25 of Set 7 | bonfim
# Processing Record 26 of Set 7 | morehead
# Processing Record 27 of Set 7 | bodden town
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | vanimo
# Processing Record 30 of Set 7 | trincomalee
# Processing Record 31 of Set 7 | auki
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | namibe
# Processing Record 34 of Set 7 | mandalgovi
# Processing Record 35 of Set 7 | umba
# Processing Record 36 of Set 7 | contamana
# Processing Record 37 of Set 7 | gizo
# Processing Record 38 of Set 7 | abonnema
# Processing Record 39 of Set 7 | craig
# Processing Record 40 of Set 7 | adrar
# Processing Record 41 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 7 | ixtapa
# Processing Record 43 of Set 7 | abrau-dyurso
# Processing Record 44 of Set 7 | vestmannaeyjar
# Processing Record 45 of Set 7 | karratha
# Processing Record 46 of Set 7 | planeta rica
# Processing Record 47 of Set 7 | tibu
# Processing Record 48 of Set 7 | delijan
# Processing Record 49 of Set 7 | eyl
# Processing Record 50 of Set 7 | duz
# City not found. Skipping...
# Processing Record 1 of Set 8 | ystad
# Processing Record 2 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 8 | yulara
# Processing Record 4 of Set 8 | necochea
# Processing Record 5 of Set 8 | solnechnyy
# Processing Record 6 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 8 | katsuura
# Processing Record 8 of Set 8 | cidreira
# Processing Record 9 of Set 8 | deputatskiy
# Processing Record 10 of Set 8 | erenhot
# Processing Record 11 of Set 8 | gedo
# Processing Record 12 of Set 8 | vilhena
# Processing Record 13 of Set 8 | camana
# Processing Record 14 of Set 8 | punta alta
# Processing Record 15 of Set 8 | perth
# Processing Record 16 of Set 8 | port hedland
# Processing Record 17 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 8 | lompoc
# Processing Record 20 of Set 8 | yerbogachen
# Processing Record 21 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 22 of Set 8 | waipawa
# Processing Record 23 of Set 8 | morganton
# Processing Record 24 of Set 8 | tezu
# Processing Record 25 of Set 8 | gap
# Processing Record 26 of Set 8 | roma
# Processing Record 27 of Set 8 | suntar
# Processing Record 28 of Set 8 | taybad
# Processing Record 29 of Set 8 | uni
# Processing Record 30 of Set 8 | kodinsk
# Processing Record 31 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 8 | bethel
# Processing Record 33 of Set 8 | omsukchan
# Processing Record 34 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 8 | la roda
# Processing Record 36 of Set 8 | resistencia
# Processing Record 37 of Set 8 | mahibadhoo
# Processing Record 38 of Set 8 | mount isa
# Processing Record 39 of Set 8 | margate
# Processing Record 40 of Set 8 | fare
# Processing Record 41 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 8 | kruisfontein
# Processing Record 43 of Set 8 | nelson bay
# Processing Record 44 of Set 8 | south lake tahoe
# Processing Record 45 of Set 8 | uruzgan
# Processing Record 46 of Set 8 | batemans bay
# Processing Record 47 of Set 8 | egvekinot
# Processing Record 48 of Set 8 | tadepallegudem
# Processing Record 49 of Set 8 | sambava
# Processing Record 50 of Set 8 | amahai
# Processing Record 1 of Set 9 | gramado
# Processing Record 2 of Set 9 | shubarshi
# Processing Record 3 of Set 9 | jalu
# Processing Record 4 of Set 9 | northam
# Processing Record 5 of Set 9 | alice springs
# Processing Record 6 of Set 9 | akyab
# Processing Record 7 of Set 9 | baruun-urt
# Processing Record 8 of Set 9 | savantvadi
# Processing Record 9 of Set 9 | sol-iletsk
# Processing Record 10 of Set 9 | battle creek
# Processing Record 11 of Set 9 | wladyslawowo
# Processing Record 12 of Set 9 | imbituba
# Processing Record 13 of Set 9 | la rinconada
# Processing Record 14 of Set 9 | majene
# Processing Record 15 of Set 9 | peniche
# Processing Record 16 of Set 9 | tabas
# Processing Record 17 of Set 9 | emporia
# Processing Record 18 of Set 9 | dinahican
# Processing Record 19 of Set 9 | port lincoln
# Processing Record 20 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 9 | krasnaya gora
# Processing Record 22 of Set 9 | ketchikan
# Processing Record 23 of Set 9 | paragominas
# Processing Record 24 of Set 9 | cherskiy
# Processing Record 25 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 9 | vestmanna
# Processing Record 27 of Set 9 | qostanay
# Processing Record 28 of Set 9 | najran
# Processing Record 29 of Set 9 | wakuya
# Processing Record 30 of Set 9 | teeli
# Processing Record 31 of Set 9 | morro bay
# Processing Record 32 of Set 9 | antofagasta
# Processing Record 33 of Set 9 | blumberg
# Processing Record 34 of Set 9 | beringovskiy
# Processing Record 35 of Set 9 | sola
# Processing Record 36 of Set 9 | port keats
# Processing Record 37 of Set 9 | pierre
# Processing Record 38 of Set 9 | san juan
# Processing Record 39 of Set 9 | sharlyk
# Processing Record 40 of Set 9 | high level
# Processing Record 41 of Set 9 | natal
# Processing Record 42 of Set 9 | nabire
# Processing Record 43 of Set 9 | ambon
# Processing Record 44 of Set 9 | kualakapuas
# Processing Record 45 of Set 9 | richards bay
# Processing Record 46 of Set 9 | gotsu
# Processing Record 47 of Set 9 | acarau
# Processing Record 48 of Set 9 | kasama
# Processing Record 49 of Set 9 | henties bay
# Processing Record 50 of Set 9 | coolum beach
# Processing Record 1 of Set 10 | biloela
# Processing Record 2 of Set 10 | portales
# Processing Record 3 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 10 | zalesovo
# Processing Record 5 of Set 10 | kaeo
# Processing Record 6 of Set 10 | sioux lookout
# Processing Record 7 of Set 10 | minudasht
# Processing Record 8 of Set 10 | hofn
# Processing Record 9 of Set 10 | acapulco
# Processing Record 10 of Set 10 | san felipe
# Processing Record 11 of Set 10 | fridley
# Processing Record 12 of Set 10 | laiya
# Processing Record 13 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 14 of Set 10 | panaba
# Processing Record 15 of Set 10 | uglegorsk
# Processing Record 16 of Set 10 | jakar
# Processing Record 17 of Set 10 | tirano
# Processing Record 18 of Set 10 | chumikan
# Processing Record 19 of Set 10 | lufilufi
# Processing Record 20 of Set 10 | pacific grove
# Processing Record 21 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 23 of Set 10 | hutang
# Processing Record 24 of Set 10 | pangai
# Processing Record 25 of Set 10 | talaya
# Processing Record 26 of Set 10 | kasempa
# Processing Record 27 of Set 10 | inhambane
# Processing Record 28 of Set 10 | niquelandia
# Processing Record 29 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 10 | biak
# Processing Record 31 of Set 10 | dod ballapur
# Processing Record 32 of Set 10 | lahad datu
# Processing Record 33 of Set 10 | guerrero negro
# Processing Record 34 of Set 10 | san andres
# Processing Record 35 of Set 10 | hirara
# Processing Record 36 of Set 10 | leningradskiy
# Processing Record 37 of Set 10 | lagoa
# Processing Record 38 of Set 10 | pangkalanbuun
# Processing Record 39 of Set 10 | ilorin
# Processing Record 40 of Set 10 | kropotkin
# Processing Record 41 of Set 10 | panukulan
# Processing Record 42 of Set 10 | moerai
# Processing Record 43 of Set 10 | horsham
# Processing Record 44 of Set 10 | grindavik
# Processing Record 45 of Set 10 | gat
# Processing Record 46 of Set 10 | lianran
# Processing Record 47 of Set 10 | klyuchi
# Processing Record 48 of Set 10 | ambovombe
# Processing Record 49 of Set 10 | ponferrada
# Processing Record 50 of Set 10 | korla
# Processing Record 1 of Set 11 | naze
# Processing Record 2 of Set 11 | georgetown
# Processing Record 3 of Set 11 | batagay
# Processing Record 4 of Set 11 | tazovskiy
# Processing Record 5 of Set 11 | gazojak
# Processing Record 6 of Set 11 | dingle
# Processing Record 7 of Set 11 | gazimurskiy zavod
# Processing Record 8 of Set 11 | caraguatay
# Processing Record 9 of Set 11 | taltal
# Processing Record 10 of Set 11 | mykhaylivka
# Processing Record 11 of Set 11 | panguna
# Processing Record 12 of Set 11 | khandyga
# Processing Record 13 of Set 11 | vuktyl
# Processing Record 14 of Set 11 | sao sebastiao do cai
# Processing Record 15 of Set 11 | marawi
# Processing Record 16 of Set 11 | okhotsk
# Processing Record 17 of Set 11 | pajacuaran
# Processing Record 18 of Set 11 | iberia
# Processing Record 19 of Set 11 | luanda
# Processing Record 20 of Set 11 | kushima
# Processing Record 21 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 11 | bambanglipuro
# Processing Record 23 of Set 11 | klaksvik
# Processing Record 24 of Set 11 | concord
# Processing Record 25 of Set 11 | sehithwa
# Processing Record 26 of Set 11 | taoudenni
# Processing Record 27 of Set 11 | grand gaube
# Processing Record 28 of Set 11 | umm kaddadah
# Processing Record 29 of Set 11 | targusor
# Processing Record 30 of Set 11 | mildura
# Processing Record 31 of Set 11 | casper
# Processing Record 32 of Set 11 | kirando
# Processing Record 33 of Set 11 | ust-omchug
# Processing Record 34 of Set 11 | dengzhou
# Processing Record 35 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 11 | xichang
# Processing Record 37 of Set 11 | shieli
# Processing Record 38 of Set 11 | pangnirtung
# Processing Record 39 of Set 11 | balkanabat
# Processing Record 40 of Set 11 | thinadhoo
# Processing Record 41 of Set 11 | muli
# Processing Record 42 of Set 11 | carlsbad
# Processing Record 43 of Set 11 | kudahuvadhoo
# Processing Record 44 of Set 11 | carauari
# Processing Record 45 of Set 11 | benemerito de las americas
# Processing Record 46 of Set 11 | midyat
# Processing Record 47 of Set 11 | svetlyy
# Processing Record 48 of Set 11 | graaff-reinet
# Processing Record 49 of Set 11 | prince rupert
# Processing Record 50 of Set 11 | barahona
# Processing Record 1 of Set 12 | chapais
# Processing Record 2 of Set 12 | kontagora
# Processing Record 3 of Set 12 | katangli
# Processing Record 4 of Set 12 | kardamas
# Processing Record 5 of Set 12 | puerto escondido
# Processing Record 6 of Set 12 | oistins
# Processing Record 7 of Set 12 | kingisepp
# Processing Record 8 of Set 12 | beloha
# Processing Record 9 of Set 12 | san cristobal
# Processing Record 10 of Set 12 | veszto
# Processing Record 11 of Set 12 | susuman
# Processing Record 12 of Set 12 | lashio
# Processing Record 13 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 12 | rio gallegos
# Processing Record 15 of Set 12 | caravelas
# Processing Record 16 of Set 12 | dovbysh
# Processing Record 17 of Set 12 | barsovo
# Processing Record 18 of Set 12 | zarechnyy
# Processing Record 19 of Set 12 | guacimo
# Processing Record 20 of Set 12 | siderno
# Processing Record 21 of Set 12 | kibala
# Processing Record 22 of Set 12 | seoul
# Processing Record 23 of Set 12 | kampot
# Processing Record 24 of Set 12 | prainha
# Processing Record 25 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 12 | aksha
# Processing Record 27 of Set 12 | anajatuba
# Processing Record 28 of Set 12 | maumere
# Processing Record 29 of Set 12 | tambura
# Processing Record 30 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 12 | nizhniy lomov
# Processing Record 32 of Set 12 | kloulklubed
# Processing Record 33 of Set 12 | baykit
# Processing Record 34 of Set 12 | evenskjaer
# City not found. Skipping...
# Processing Record 35 of Set 12 | mattru
# Processing Record 36 of Set 12 | puerto colombia
# Processing Record 37 of Set 12 | pinyug
# Processing Record 38 of Set 12 | serramanna
# Processing Record 39 of Set 12 | nishihara
# Processing Record 40 of Set 12 | astoria
# Processing Record 41 of Set 12 | nelson
# Processing Record 42 of Set 12 | kendari
# Processing Record 43 of Set 12 | ranong
# Processing Record 44 of Set 12 | inongo
# Processing Record 45 of Set 12 | tiznit
# Processing Record 46 of Set 12 | nurobod
# Processing Record 47 of Set 12 | aklavik
# Processing Record 48 of Set 12 | kavieng
# Processing Record 49 of Set 12 | parabel
# Processing Record 50 of Set 12 | dongsheng
# Processing Record 1 of Set 13 | cartagena del chaira
# Processing Record 2 of Set 13 | shimoda
# Processing Record 3 of Set 13 | muros
# Processing Record 4 of Set 13 | alta gracia
# Processing Record 5 of Set 13 | yuzhnyy
# Processing Record 6 of Set 13 | ligayan
# Processing Record 7 of Set 13 | shache
# Processing Record 8 of Set 13 | calvinia
# Processing Record 9 of Set 13 | edgewater
# Processing Record 10 of Set 13 | zaranj
# Processing Record 11 of Set 13 | lata
# Processing Record 12 of Set 13 | morecambe
# Processing Record 13 of Set 13 | zeya
# Processing Record 14 of Set 13 | ghanzi
# Processing Record 15 of Set 13 | teplyk
# Processing Record 16 of Set 13 | letlhakeng
# Processing Record 17 of Set 13 | omboue
# Processing Record 18 of Set 13 | srandakan
# Processing Record 19 of Set 13 | port hardy
# Processing Record 20 of Set 13 | watertown
# Processing Record 21 of Set 13 | gaurnadi
# Processing Record 22 of Set 13 | balotra
# Processing Record 23 of Set 13 | pandan
# Processing Record 24 of Set 13 | hilotongan
# Processing Record 25 of Set 13 | nicoya
# Processing Record 26 of Set 13 | pong
# Processing Record 27 of Set 13 | malakal
# Processing Record 28 of Set 13 | mwinilunga
# Processing Record 29 of Set 13 | groningen
# Processing Record 30 of Set 13 | gamboma
# Processing Record 31 of Set 13 | moron
# Processing Record 32 of Set 13 | ravar
# Processing Record 33 of Set 13 | itacare
# Processing Record 34 of Set 13 | berbera
# Processing Record 35 of Set 13 | bereda
# Processing Record 36 of Set 13 | andenes
# Processing Record 37 of Set 13 | inta
# Processing Record 38 of Set 13 | shaoyang
# Processing Record 39 of Set 13 | gornopravdinsk
# Processing Record 40 of Set 13 | olinda
# Processing Record 41 of Set 13 | saint-pierre
# Processing Record 42 of Set 13 | mount vernon
# Processing Record 43 of Set 13 | shenjiamen
# Processing Record 44 of Set 13 | svetlaya
# Processing Record 45 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 13 | sakaiminato
# Processing Record 47 of Set 13 | ginir
# Processing Record 48 of Set 13 | isiro
# Processing Record 49 of Set 13 | hailar
# Processing Record 50 of Set 13 | poum
# Processing Record 1 of Set 14 | myitkyina
# Processing Record 2 of Set 14 | igrim
# Processing Record 3 of Set 14 | soe
# Processing Record 4 of Set 14 | berlevag
# Processing Record 5 of Set 14 | henzada
# City not found. Skipping...
# Processing Record 6 of Set 14 | hami
# Processing Record 7 of Set 14 | hohhot
# Processing Record 8 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 14 | north bend
# Processing Record 10 of Set 14 | narrabri
# Processing Record 11 of Set 14 | kisangani
# Processing Record 12 of Set 14 | raga
# Processing Record 13 of Set 14 | ossora
# Processing Record 14 of Set 14 | canutama
# Processing Record 15 of Set 14 | celestun
# Processing Record 16 of Set 14 | quatre cocos
# Processing Record 17 of Set 14 | mugla
# Processing Record 18 of Set 14 | jardim
# Processing Record 19 of Set 14 | tessalit
# Processing Record 20 of Set 14 | sylvania
# Processing Record 21 of Set 14 | ola
# Processing Record 22 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 23 of Set 14 | goderich
# Processing Record 24 of Set 14 | dunedin
# Processing Record 25 of Set 14 | genc
# Processing Record 26 of Set 14 | tucurui
# Processing Record 27 of Set 14 | gondanglegi
# Processing Record 28 of Set 14 | kavaratti
# Processing Record 29 of Set 14 | tura
# Processing Record 30 of Set 14 | cotacachi
# Processing Record 31 of Set 14 | harper
# Processing Record 32 of Set 14 | bhainsdehi
# Processing Record 33 of Set 14 | mbandaka
# Processing Record 34 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 14 | timberlake
# Processing Record 36 of Set 14 | ostrovnoy
# Processing Record 37 of Set 14 | nyimba
# Processing Record 38 of Set 14 | pundaguitan
# Processing Record 39 of Set 14 | yinchuan
# Processing Record 40 of Set 14 | jaen
# Processing Record 41 of Set 14 | apac
# Processing Record 42 of Set 14 | sabha
# Processing Record 43 of Set 14 | aden
# Processing Record 44 of Set 14 | mehamn
# Processing Record 45 of Set 14 | kristiinankaupunki
# Processing Record 46 of Set 14 | carira
# Processing Record 47 of Set 14 | djenne
# Processing Record 48 of Set 14 | praia da vitoria
# Processing Record 49 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 50 of Set 14 | pimentel
# Processing Record 1 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 2 of Set 15 | yermish
# Processing Record 3 of Set 15 | missoula
# Processing Record 4 of Set 15 | novotalitsy
# City not found. Skipping...
# Processing Record 5 of Set 15 | kiama
# Processing Record 6 of Set 15 | lewisporte
# Processing Record 7 of Set 15 | cam ranh
# Processing Record 8 of Set 15 | ballina
# Processing Record 9 of Set 15 | taywarah
# Processing Record 10 of Set 15 | banda aceh
# Processing Record 11 of Set 15 | agua verde
# Processing Record 12 of Set 15 | izberbash
# Processing Record 13 of Set 15 | araouane
# Processing Record 14 of Set 15 | khvoynaya
# Processing Record 15 of Set 15 | chimbarongo
# Processing Record 16 of Set 15 | puri
# Processing Record 17 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 15 | sangar
# Processing Record 19 of Set 15 | carlos antonio lopez
# Processing Record 20 of Set 15 | padang
# Processing Record 21 of Set 15 | florida
# Processing Record 22 of Set 15 | yialos
# City not found. Skipping...
# Processing Record 23 of Set 15 | samdrup jongkhar
# Processing Record 24 of Set 15 | labuhan
# Processing Record 25 of Set 15 | alice
# Processing Record 26 of Set 15 | yaan
# Processing Record 27 of Set 15 | bairiki
# Processing Record 28 of Set 15 | olafsvik
# Processing Record 29 of Set 15 | takoradi
# Processing Record 30 of Set 15 | hammerfest
# Processing Record 31 of Set 15 | mongu
# Processing Record 32 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 15 | severnyy-kospashskiy
# Processing Record 34 of Set 15 | vikhorevka
# Processing Record 35 of Set 15 | impfondo
# Processing Record 36 of Set 15 | fort nelson
# Processing Record 37 of Set 15 | severobaykalsk
# Processing Record 38 of Set 15 | ojinaga
# Processing Record 39 of Set 15 | qasigiannguit
# Processing Record 40 of Set 15 | ratnagiri
# Processing Record 41 of Set 15 | viedma
# Processing Record 42 of Set 15 | nizwa
# Processing Record 43 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 15 | japura
# Processing Record 45 of Set 15 | la romana
# Processing Record 46 of Set 15 | bud
# Processing Record 47 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 15 | boo
# Processing Record 50 of Set 15 | sabang
# Processing Record 1 of Set 16 | si satchanalai
# Processing Record 2 of Set 16 | ribeira brava
# Processing Record 3 of Set 16 | gold coast
# Processing Record 4 of Set 16 | antsohihy
# Processing Record 5 of Set 16 | magadan
# Processing Record 6 of Set 16 | kawalu
# Processing Record 7 of Set 16 | barranca
# Processing Record 8 of Set 16 | yunjinghong
# City not found. Skipping...
# Processing Record 9 of Set 16 | acaponeta
# Processing Record 10 of Set 16 | tonstad
# Processing Record 11 of Set 16 | broken hill
# Processing Record 12 of Set 16 | kongolo
# Processing Record 13 of Set 16 | yar-sale
# Processing Record 14 of Set 16 | petatlan
# Processing Record 15 of Set 16 | leh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hobart      AU -42.8794  147.3294     49.26        75          40
# 1        Pakokku      MM  21.3333   95.1000     79.59        82         100
# 2      Lisakovsk      KZ  52.5369   62.4936     67.51        76          22
# 3     Turukhansk      RU  65.8167   87.9833     59.90        76          44
# 4           Mama      RU  58.3106  112.8986     57.81        86         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 696  Broken Hill      AU -31.9500  141.4333     54.82        65           0
# 697      Kongolo      CD  -5.3833   27.0000     74.39        40          33
# 698     Yar-Sale      RU  66.8333   70.8333     54.73        98         100
# 699     Petatlan      MX  17.5167 -101.2667     89.40        84          38
# 700          Leh      IN  34.1667   77.5833     60.49        56          45
#
#      Wind Speed Current description
# 0          1.99    scattered clouds
# 1          9.46     overcast clouds
# 2          5.82          few clouds
# 3          6.06    scattered clouds
# 4          3.38     overcast clouds
# ..          ...                 ...
# 696       19.98           clear sky
# 697        2.44    scattered clouds
# 698       14.85          light rain
# 699        4.25    scattered clouds
# 700        6.69    scattered clouds
#
# [701 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
